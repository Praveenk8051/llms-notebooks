# %% [markdown]
# ### Youtube Video Summarizer

# %%
from IPython.display import Image
Image(filename='youtube_summarizer.JPG',width=800, height=400)

# %%
# !pip install yt_dlp
# !pip install git+https://github.com/openai/whisper.git
# Out:
# Requirement already satisfied: yt_dlp in c:\users\prave\desktop\hobbyproject\customer_app\lib\site-packages (2024.10.22)
# Requirement already satisfied: brotli in c:\users\prave\desktop\hobbyproject\customer_app\lib\site-packages (from yt_dlp) (1.1.0)
# Requirement already satisfied: certifi in c:\users\prave\desktop\hobbyproject\customer_app\lib\site-packages (from yt_dlp) (2024.12.14)
# Requirement already satisfied: mutagen in c:\users\prave\desktop\hobbyproject\customer_app\lib\site-packages (from yt_dlp) (1.47.0)
# Requirement already satisfied: pycryptodomex in c:\users\prave\desktop\hobbyproject\customer_app\lib\site-packages (from yt_dlp) (3.21.0)
# Requirement already satisfied: requests<3,>=2.32.2 in c:\users\prave\desktop\hobbyproject\customer_app\lib\site-packages (from yt_dlp) (2.32.3)
# Requirement already satisfied: urllib3<3,>=1.26.17 in c:\users\prave\desktop\hobbyproject\customer_app\lib\site-packages (from yt_dlp) (2.2.3)
# Requirement already satisfied: websockets>=13.0 in c:\users\prave\desktop\hobbyproject\customer_app\lib\site-packages (from yt_dlp) (13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\prave\desktop\hobbyproject\customer_app\lib\site-packages (from requests<3,>=2.32.2->yt_dlp) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\prave\desktop\hobbyproject\customer_app\lib\site-packages (from requests<3,>=2.32.2->yt_dlp) (3.10)
# Collecting git+https://github.com/openai/whisper.git
#   Cloning https://github.com/openai/whisper.git to c:\users\prave\appdata\local\temp\pip-req-build-z6tf1k9z
#   Resolved https://github.com/openai/whisper.git to commit dd4d010d2c585bc70aeddd166cd3e26b0bb62f31
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting more-itertools (from openai-whisper==20240930)
#   Using cached more_itertools-10.5.0-py3-none-any.whl.metadata (36 kB)
# Collecting numba (from openai-whisper==20240930)
#   Using cached numba-0.58.1-cp38-cp38-win_amd64.whl.metadata (2.8 kB)
# Requirement already satisfied: numpy in c:\users\prave\desktop\hobbyproject\customer_app\lib\site-packages (from openai-whisper==20240930) (1.24.4)
# Requirement already satisfied: tiktoken in c:\users\prave\desktop\hobbyproject\customer_app\lib\site-packages (from openai-whisper==20240930) (0.7.0)
# Collecting torch (from openai-whisper==20240930)
#   Using cached torch-2.4.1-cp38-cp38-win_amd64.whl.metadata (27 kB)
# Requirement already satisfied: tqdm in c:\users\prave\desktop\hobbyproject\customer_app\lib\site-packages (from openai-whisper==20240930) (4.67.1)
# Collecting llvmlite<0.42,>=0.41.0dev0 (from numba->openai-whisper==20240930)
#   Using cached llvmlite-0.41.1-cp38-cp38-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: importlib-metadata in c:\users\prave\desktop\hobbyproject\customer_app\lib\site-packages (from numba->openai-whisper==20240930) (8.5.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\prave\desktop\hobbyproject\customer_app\lib\site-packages (from tiktoken->openai-whisper==20240930) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in c:\users\prave\desktop\hobbyproject\customer_app\lib\site-packages (from tiktoken->openai-whisper==20240930) (2.32.3)
# Collecting filelock (from torch->openai-whisper==20240930)
#   Using cached filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\prave\desktop\hobbyproject\customer_app\lib\site-packages (from torch->openai-whisper==20240930) (4.12.2)
# Requirement already satisfied: sympy in c:\users\prave\desktop\hobbyproject\customer_app\lib\site-packages (from torch->openai-whisper==20240930) (1.13.3)
# Collecting networkx (from torch->openai-whisper==20240930)
#   Using cached networkx-3.1-py3-none-any.whl.metadata (5.3 kB)
# Collecting jinja2 (from torch->openai-whisper==20240930)
#   Using cached jinja2-3.1.5-py3-none-any.whl.metadata (2.6 kB)
# Collecting fsspec (from torch->openai-whisper==20240930)
#   Using cached fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: colorama in c:\users\prave\desktop\hobbyproject\customer_app\lib\site-packages (from tqdm->openai-whisper==20240930) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\prave\desktop\hobbyproject\customer_app\lib\site-packages (from requests>=2.26.0->tiktoken->openai-whisper==20240930) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\prave\desktop\hobbyproject\customer_app\lib\site-packages (from requests>=2.26.0->tiktoken->openai-whisper==20240930) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\prave\desktop\hobbyproject\customer_app\lib\site-packages (from requests>=2.26.0->tiktoken->openai-whisper==20240930) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\prave\desktop\hobbyproject\customer_app\lib\site-packages (from requests>=2.26.0->tiktoken->openai-whisper==20240930) (2024.12.14)
# Requirement already satisfied: zipp>=3.20 in c:\users\prave\desktop\hobbyproject\customer_app\lib\site-packages (from importlib-metadata->numba->openai-whisper==20240930) (3.20.2)
# Collecting MarkupSafe>=2.0 (from jinja2->torch->openai-whisper==20240930)
#   Using cached MarkupSafe-2.1.5-cp38-cp38-win_amd64.whl.metadata (3.1 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\prave\desktop\hobbyproject\customer_app\lib\site-packages (from sympy->torch->openai-whisper==20240930) (1.3.0)
# Using cached more_itertools-10.5.0-py3-none-any.whl (60 kB)
# Using cached numba-0.58.1-cp38-cp38-win_amd64.whl (2.6 MB)
# Using cached torch-2.4.1-cp38-cp38-win_amd64.whl (199.4 MB)
# Using cached llvmlite-0.41.1-cp38-cp38-win_amd64.whl (28.1 MB)
# Using cached filelock-3.16.1-py3-none-any.whl (16 kB)
# Using cached fsspec-2024.12.0-py3-none-any.whl (183 kB)
# Using cached jinja2-3.1.5-py3-none-any.whl (134 kB)
# Using cached networkx-3.1-py3-none-any.whl (2.1 MB)
# Using cached MarkupSafe-2.1.5-cp38-cp38-win_amd64.whl (17 kB)
# Building wheels for collected packages: openai-whisper
#   Building wheel for openai-whisper (pyproject.toml): started
#   Building wheel for openai-whisper (pyproject.toml): finished with status 'done'
#   Created wheel for openai-whisper: filename=openai_whisper-20240930-py3-none-any.whl size=813014 sha256=4afdfa0619d2c6f2cc99d46a990e9f938c55d9c76812af8f8bd98cfedaeafb57
#   Stored in directory: C:\Users\prave\AppData\Local\Temp\pip-ephem-wheel-cache-ryly4tyd\wheels\a7\70\18\b7693c07b1d18b3dafb328f5d0496aa0d41a9c09ef332fd8e6
# Successfully built openai-whisper
# Installing collected packages: networkx, more-itertools, MarkupSafe, llvmlite, fsspec, filelock, numba, jinja2, torch, openai-whisper
# Successfully installed MarkupSafe-2.1.5 filelock-3.16.1 fsspec-2024.12.0 jinja2-3.1.5 llvmlite-0.41.1 more-itertools-10.5.0 networkx-3.1 numba-0.58.1 openai-whisper-20240930 torch-2.4.1
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git 'C:\Users\prave\AppData\Local\Temp\pip-req-build-z6tf1k9z'

# %%
from langchain_openai.embeddings.base import OpenAIEmbeddings
from langchain_text_splitters.character import CharacterTextSplitter
#from langchain_openai import OpenAI
from langchain_openai import ChatOpenAI
#from langchain_community.llms import OpenAI
from langchain_community.document_loaders.url_selenium import SeleniumURLLoader
from langchain_core.prompts.prompt import PromptTemplate
from langchain_core.messages import HumanMessage
import os

# %%
ChatOpenAI.api_key=os.getenv("OPENAI_API_KEY2")

# %%
# Download

import yt_dlp

def download_mp4_from_youtube(url):
    # Set the options for the download
    filename = 'lecuninterview.mp4'
    ydl_opts = {
        'format': 'bestvideo[ext=mp4]+bestaudio[ext=m4a]/best[ext=mp4]',
        'outtmpl': filename,
        'quiet': True,
    }

    # Download the video file
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        result = ydl.extract_info(url, download=True)

url = "https://www.youtube.com/watch?v=mBjPyte2ZZo"
download_mp4_from_youtube(url)
# Out:
# Deprecated Feature: Support for Python version 3.8 has been deprecated. Please update to Python 3.9 or above
# WARNING: [youtube] Falling back to generic n function search
#          player = https://www.youtube.com/s/player/03dbdfab/player_ias.vflset/en_US/base.js
# WARNING: [youtube] mBjPyte2ZZo: nsig extraction failed: Some formats may be missing
#          n = vBcfzKorCpzplXUhZ ; player = https://www.youtube.com/s/player/03dbdfab/player_ias.vflset/en_US/base.js
# WARNING: [youtube] Falling back to generic n function search
#          player = https://www.youtube.com/s/player/03dbdfab/player_ias.vflset/en_US/base.js
# WARNING: [youtube] mBjPyte2ZZo: nsig extraction failed: Some formats may be missing
#          n = OVboSAprpp8KHrJHa ; player = https://www.youtube.com/s/player/03dbdfab/player_ias.vflset/en_US/base.js
# ERROR: You have requested merging of multiple formats but ffmpeg is not installed. Aborting due to --abort-on-error
# ---------------------------------------------------------------------------
# DownloadError                             Traceback (most recent call last)
# Cell In[1], line 19
#      16         result = ydl.extract_info(url, download=True)
#      18 url = "https://www.youtube.com/watch?v=mBjPyte2ZZo"
# ---> 19 download_mp4_from_youtube(url)
#
# Cell In[1], line 16, in download_mp4_from_youtube(url)
#      14 # Download the video file
#      15 with yt_dlp.YoutubeDL(ydl_opts) as ydl:
# ---> 16     result = ydl.extract_info(url, download=True)
#
# File ~\Desktop\HobbyProject\customer_app\lib\site-packages\yt_dlp\YoutubeDL.py:1614, in YoutubeDL.extract_info(self, url, download, ie_key, extra_info, process, force_generic_extractor)
#    1612             raise ExistingVideoReached
#    1613         break
# -> 1614     return self.__extract_info(url, self.get_info_extractor(key), download, extra_info, process)
#    1615 else:
#    1616     extractors_restricted = self.params.get('allowed_extractors') not in (None, ['default'])
#
# File ~\Desktop\HobbyProject\customer_app\lib\site-packages\yt_dlp\YoutubeDL.py:1625, in YoutubeDL._handle_extraction_exceptions.<locals>.wrapper(self, *args, **kwargs)
#    1623 while True:
#    1624     try:
# -> 1625         return func(self, *args, **kwargs)
#    1626     except (CookieLoadError, DownloadCancelled, LazyList.IndexError, PagedList.IndexError):
#    1627         raise
#
# File ~\Desktop\HobbyProject\customer_app\lib\site-packages\yt_dlp\YoutubeDL.py:1781, in YoutubeDL.__extract_info(self, url, ie, download, extra_info, process)
#    1779 if process:
#    1780     self._wait_for_video(ie_result)
# -> 1781     return self.process_ie_result(ie_result, download, extra_info)
#    1782 else:
#    1783     return ie_result
#
# File ~\Desktop\HobbyProject\customer_app\lib\site-packages\yt_dlp\YoutubeDL.py:1840, in YoutubeDL.process_ie_result(self, ie_result, download, extra_info)
#    1838 if result_type == 'video':
#    1839     self.add_extra_info(ie_result, extra_info)
# -> 1840     ie_result = self.process_video_result(ie_result, download=download)
#    1841     self._raise_pending_errors(ie_result)
#    1842     additional_urls = (ie_result or {}).get('additional_urls')
#
# File ~\Desktop\HobbyProject\customer_app\lib\site-packages\yt_dlp\YoutubeDL.py:3014, in YoutubeDL.process_video_result(self, info_dict, download)
#    3012 downloaded_formats.append(new_info)
#    3013 try:
# -> 3014     self.process_info(new_info)
#    3015 except MaxDownloadsReached:
#    3016     max_downloads_reached = True
#
# File ~\Desktop\HobbyProject\customer_app\lib\site-packages\yt_dlp\YoutubeDL.py:178, in _catch_unsafe_extension_error.<locals>.wrapper(self, *args, **kwargs)
#     175 @functools.wraps(func)
#     176 def wrapper(self, *args, **kwargs):
#     177     try:
# --> 178         return func(self, *args, **kwargs)
#     179     except _UnsafeExtensionError as error:
#     180         self.report_error(
#     181             f'The extracted extension ({error.extension!r}) is unusual '
#     182             'and will be skipped for safety reasons. '
#     183             f'If you believe this is an error{bug_reports_message(",")}')
#
# File ~\Desktop\HobbyProject\customer_app\lib\site-packages\yt_dlp\YoutubeDL.py:3440, in YoutubeDL.process_info(self, info_dict)
#    3438 msg = 'You have requested merging of multiple formats but ffmpeg is not installed'
#    3439 if not self.params.get('ignoreerrors'):
# -> 3440     self.report_error(f'{msg}. Aborting due to --abort-on-error')
#    3441     return
#    3442 self.report_warning(f'{msg}. The formats won\'t be merged')
#
# File ~\Desktop\HobbyProject\customer_app\lib\site-packages\yt_dlp\YoutubeDL.py:1091, in YoutubeDL.report_error(self, message, *args, **kwargs)
#    1086 def report_error(self, message, *args, **kwargs):
#    1087     """
#    1088     Do the same as trouble, but prefixes the message with 'ERROR:', colored
#    1089     in red if stderr is a tty file.
#    1090     """
# -> 1091     self.trouble(f'{self._format_err("ERROR:", self.Styles.ERROR)} {message}', *args, **kwargs)
#
# File ~\Desktop\HobbyProject\customer_app\lib\site-packages\yt_dlp\YoutubeDL.py:1030, in YoutubeDL.trouble(self, message, tb, is_error)
#    1028     else:
#    1029         exc_info = sys.exc_info()
# -> 1030     raise DownloadError(message, exc_info)
#    1031 self._download_retcode = 1
#
# DownloadError: ERROR: You have requested merging of multiple formats but ffmpeg is not installed. Aborting due to --abort-on-error

# %%
# Transcribe
import whisper

model = whisper.load_model("base")
result = model.transcribe("lecuninterview.mp4")
print(result['text'])

# %%
# Save
with open ('text.txt', 'w') as file:  
    file.write(result['text'])

# %%
rom langchain import OpenAI, LLMChain
from langchain.chains.mapreduce import MapReduceChain
from langchain.prompts import PromptTemplate
from langchain.chains.summarize import load_summarize_chain

llm = OpenAI(model_name="gpt-3.5-turbo", temperature=0)

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000, chunk_overlap=0, separators=[" ", ",", "\n"]
)

# %%
from langchain.docstore.document import Document

with open('text.txt') as f:
    text = f.read()

texts = text_splitter.split_text(text)
docs = [Document(page_content=t) for t in texts[:4]]

# %%
from langchain.chains.summarize import load_summarize_chain
import textwrap

chain = load_summarize_chain(llm, chain_type="map_reduce")

output_summary = chain.run(docs)
wrapped_text = textwrap.fill(output_summary, width=100)
print(wrapped_text)

# %%
print(chain.llm_chain.prompt.template)

# %%
prompt_template = """Write a concise bullet point summary of the following:

{text}

CONSCISE SUMMARY IN BULLET POINTS:"""

BULLET_POINT_PROMPT = PromptTemplate(template=prompt_template,
                        input_variables=["text"])

# %%
chain = load_summarize_chain(llm,
                             chain_type="stuff",
                             prompt=BULLET_POINT_PROMPT)

output_summary = chain.run(docs)

wrapped_text = textwrap.fill(output_summary,
                             width=1000,
                             break_long_words=False,
                             replace_whitespace=False)
print(wrapped_text)

# %%
chain = load_summarize_chain(llm, chain_type="refine")
output_summary = chain.run(docs)
wrapped_text = textwrap.fill(output_summary, width=100)
print(wrapped_text)

# %%
# Storage 

import yt_dlp

def download_mp4_from_youtube(urls, job_id):
    # This will hold the titles and authors of each downloaded video
    video_info = []

    for i, url in enumerate(urls):
        # Set the options for the download
        file_temp = f'./{job_id}_{i}.mp4'
        ydl_opts = {
            'format': 'bestvideo[ext=mp4]+bestaudio[ext=m4a]/best[ext=mp4]',
            'outtmpl': file_temp,
            'quiet': True,
        }

        # Download the video file
        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            result = ydl.extract_info(url, download=True)
            title = result.get('title', "")
            author = result.get('uploader', "")

        # Add the title and author to our list
        video_info.append((file_temp, title, author))

    return video_info
urls=["https://www.youtube.com/watch?v=mBjPyte2ZZo&t=78s",
    "https://www.youtube.com/watch?v=cjs7QKJNVYM",]
vides_details = download_mp4_from_youtube(urls, 1)

# %%
import whisper

# load the model
model = whisper.load_model("base")

# iterate through each video and transcribe
results = []
for video in vides_details:
    result = model.transcribe(video[0])
    results.append( result['text'] )
    print(f"Transcription for {video[0]}:\n{result['text']}\n")

with open ('text.txt', 'w') as file:  
    file.write(results['text'])

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# Load the texts
with open('text.txt') as f:
    text = f.read()
texts = text_splitter.split_text(text)

# Split the documents
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000, chunk_overlap=0, separators=[" ", ",", "\n"]
    )
texts = text_splitter.split_text(text)

# %%
from langchain.docstore.document import Document

docs = [Document(page_content=t) for t in texts[:4]]

# %%
from langchain.vectorstores import DeepLake
from langchain.embeddings.openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(model='text-embedding-ada-002')

# create Deep Lake dataset
# TODO: use your organization id here. (by default, org id is your username)
my_activeloop_org_id = "<YOUR-ACTIVELOOP-ORG-ID>"
my_activeloop_dataset_name = "langchain_course_youtube_summarizer"
dataset_path = f"hub://{my_activeloop_org_id}/{my_activeloop_dataset_name}"

db = DeepLake(dataset_path=dataset_path, embedding_function=embeddings)
db.add_documents(docs)

# %%
retriever = db.as_retriever()
retriever.search_kwargs['distance_metric'] = 'cos'
retriever.search_kwargs['k'] = 4

# %%
from langchain.prompts import PromptTemplate
prompt_template = """Use the following pieces of transcripts from a video to answer the question in bullet points and summarized. If you don't know the answer, just say that you don't know, don't try to make up an answer.

{context}

Question: {question}
Summarized answer in bullter points:"""
PROMPT = PromptTemplate(
    template=prompt_template, input_variables=["context", "question"]
)

# %%
from langchain.chains import RetrievalQA

chain_type_kwargs = {"prompt": PROMPT}
qa = RetrievalQA.from_chain_type(llm=llm,
                                 chain_type="stuff",
                                 retriever=retriever,
                                 chain_type_kwargs=chain_type_kwargs)

print(qa.run("Summarize the mentions of google according to their AI program"))
